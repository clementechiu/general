# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # Import Libraries

# %%
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, precision_score, recall_score, accuracy_score, classification_report, precision_recall_curve, accuracy_score, roc_auc_score
from urllib.request import urlretrieve
import seaborn as sns
import shap

# %% [markdown]
# # Import data

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %% [markdown]
# # Data Understanding

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
test.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
train.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test.isna().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# We create a feature using the cabin letter.
train['cabin_letter'] = train['Cabin'].str[0]
test['cabin_letter'] = test['Cabin'].str[0]

# We create lists with the features according to their types
numeric = ['Age','Fare']
categorical = ['Pclass','Sex', 'SibSp','Parch','Embarked', 'cabin_letter']

# %%
#We create an histogram for each numerical feature to understand their distribution and to spot any outliers 
for feature in numeric:
    train[feature].hist()
    plt.title(feature)
    plt.show()

# %%
# We explore the number of observations available for each category
for feature in categorical:
    train[feature].value_counts().plot(kind='bar')
    plt.title(feature)
    plt.xlabel('Categories')
    plt.ylabel('Count')
    plt.show()

# %% [markdown]
# ### Relationship between features and target

# %%
# We explore the relationship of each categorical feature with the survival rate. 
# We do this by computing the mean survival rate for each category and plotting the values.
for feature in categorical:
    grouped = train[[feature, 'Survived']].groupby(by=[feature]).mean()
    grouped.plot(kind='bar')
    plt.title(feature)
    plt.xlabel('Category')
    plt.ylabel('% of survivors ')
    plt.show()
    plt.show()

# %%
# We compute the correlation of each numerical feature with the label
correlations = train[numeric +['Survived']].corr()['Survived']
correlations
# Out:
# Age        -0.077221
# Fare        0.257307
# Survived    1.000000
# Name: Survived, dtype: float64

# %%
# We explore the distribution of the numerical features comparing those who survived and those who didn´t
for feature in numeric:
    sns.boxplot(x='Survived', y=feature, data=train)
    plt.title(f'Box Plot of {feature} by Survival')
    plt.show()

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# Fill null values of features with missing data

# %%
# Fill null values of age and fare
train['Age'] = train['Age'].fillna(train['Age'].median())
test['Age'] = test['Age'].fillna(train['Age'].median())
train['Fare'] = train['Fare'].fillna(train['Fare'].median())
test['Fare'] = test['Fare'].fillna(train['Fare'].median())

# %%
# We create a new feature with the family size
train['FamilySize'] = train['SibSp'] + train['Parch']
test['FamilySize'] = test['SibSp'] + test['Parch']

# %% [markdown]
# ## One Hot Encoding

# %%
# We get only the features we will use
features = ['Pclass', 'Sex', 'Age', 'SibSp',
       'Parch', 'Fare', 'Embarked', 'cabin_letter',
       'FamilySize']

# Train val split
X_train, X_val, y_train, y_val = train_test_split(train[features], train['Survived'] , test_size = 0.3)

# We create a similar dataframe for the test data
X_test = test[features]

# %%
# We get the non categorical column names in a list
non_categorical = [column for column in X_train if column not in categorical]

# Create the ColumnTransformer with OneHotEncoder
preprocessor = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(handle_unknown='ignore', sparse_output=False), categorical)
    ],
    remainder='passthrough'  # Keeps the rest of the columns unchanged
)

# Fit the preprocessor on the training data
preprocessor.fit(X_train)

# Transform the training data
X_train_encoded = preprocessor.transform(X_train)
X_train_encoded = pd.DataFrame(X_train_encoded, columns=preprocessor.get_feature_names_out())

cat_feature_names = preprocessor.named_transformers_['cat'].get_feature_names_out(categorical)
# Rename the columns
X_train_encoded.columns = list(cat_feature_names) + non_categorical

#Transform the test and validation data and repeat the same process
X_test_encoded = preprocessor.transform(X_test)
X_test_encoded = pd.DataFrame(X_test_encoded, columns=preprocessor.get_feature_names_out())
X_test_encoded.columns = list(cat_feature_names) + non_categorical

X_val_encoded = preprocessor.transform(X_val)
X_val_encoded = pd.DataFrame(X_val_encoded, columns=preprocessor.get_feature_names_out())
X_val_encoded.columns = list(cat_feature_names) + non_categorical

# Convert one-hot encoded columns to int
X_train_encoded[cat_feature_names] = X_train_encoded[cat_feature_names].astype(int)
X_val_encoded[cat_feature_names] = X_val_encoded[cat_feature_names].astype(int)
X_test_encoded[cat_feature_names] = X_test_encoded[cat_feature_names].astype(int)


# Rename the columns
X_test_encoded.columns = list(cat_feature_names) + non_categorical

# %% [markdown]
# # Model Estimation

# %%
# Create the XGBoost Classifier
classifier = xgb.XGBClassifier(objective='binary:logistic')
# Fit model on training data
classifier.fit(X_train_encoded, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
# We get both probability predictions as well as class predictions to compute evaluation metrics
preds_val = classifier.predict_proba(X_val_encoded)
preds_1 = [sublist[1] for sublist in preds_val]
preds_class = classifier.predict(X_val_encoded)

# %%
# We get the accuracy obtained
print (f"Accuracy score = {accuracy_score(y_val, preds_class)}")
# Out:
# Accuracy score = 0.8022388059701493

# %%
# We get the confusion matrix for the predefined threshold
confusion_matrix(y_val, preds_class)
# Out:
# array([[145,  18],
#        [ 35,  70]])

# %%
# We plot the precision and recall values for different thresholds
precision, recall, thresholds = precision_recall_curve(y_val, preds_1)
plt.plot(thresholds, precision[1:], label='Precision', color='blue')
plt.plot(thresholds, recall[1:], label='Recall', color='green')
plt.title('Precision and Recall Curves Versus Thresholds')
plt.xlabel('Thresholds')
plt.ylabel('Precision/Recall Values')
plt.legend()

plt.show()

# %% [markdown]
# ## Evaluation and Interpretation

# %%
#Evaluation

# Function to get top features based on 'gain' importance
def get_top_features_by_gain(classifier, top_n=10):
    gain = classifier.get_booster().get_score(importance_type='gain')
    gain_list = [(key, value) for key, value in gain.items()]
    gain_list.sort(key=lambda x: x[1], reverse=True)
    top_features = [item[0] for item in gain_list][:top_n]
    gain_values = [item[1] for item in gain_list][:top_n]
    return top_features, gain_values


# Function to add predictions to the validation set and create deciles
def add_predictions_and_create_deciles(X_val_encoded, preds_1):
    X_val_encoded['preds_1'] = preds_1
    X_val_encoded['decile'] = pd.qcut(X_val_encoded['preds_1'], 10, labels=False)
    return X_val_encoded


# Function to create a styled pivot table
def create_styled_pivot_table(X_val_encoded, top_feature_names):
    pt = X_val_encoded.pivot_table(values=top_feature_names, index='decile', aggfunc='mean')
    st = pt.style.background_gradient(cmap='viridis')
    return st


# Function to plot precision and recall curves and get the precision and recall values for each threshold
def plot_precision_recall_curve(y_val, preds_1):
    precision, recall, thresholds = precision_recall_curve(y_val, preds_1)
    precision, recall, thresholds = precision_recall_curve(y_val, preds_1)
    plt.plot(thresholds, precision[1:], label='Precision', color='blue')
    plt.plot(thresholds, recall[1:], label='Recall', color='green')
    plt.title('Precision and Recall Curves Versus Thresholds')
    plt.xlabel('Thresholds')
    plt.ylabel('Precision/Recall Values')
    plt.legend()
    plt.show()
    return precision, recall, thresholds


# Function to find the best threshold where precision and recall are closest
def find_best_threshold(precision, recall, thresholds):
    difference = np.abs(precision - recall)
    index = np.argmin(difference)
    best_threshold = thresholds[index]
    return best_threshold


# Function to calculate F1 scores across thresholds
def calculate_f1_scores(y_val, preds_1, thresholds):
    f1_scores = [f1_score(y_val, preds_1 > threshold) for threshold in thresholds]
    return f1_scores


# Function to plot F1 score vs. threshold
def plot_f1_score_vs_threshold(f1_scores, thresholds):
    plt.plot(thresholds, f1_scores)
    plt.title('F1 Score vs Threshold')
    plt.show()


# Function to plot SHAP summary plot
def plot_shap_summary(classifier, X_val_encoded):
    explainer = shap.TreeExplainer(classifier, X_val_encoded)
    shap_values = explainer.shap_values(X_val_encoded)
    shap.summary_plot(shap_values, X_val_encoded)


# Function to calculate ROC AUC score
def calculate_roc_auc_score(y_val, preds_1):
    return roc_auc_score(y_val, preds_1)

# %%
top_features, gain_values = get_top_features_by_gain(classifier)
print(top_features)
# Out:
# ['Sex_female', 'Pclass_3', 'cabin_letter_nan', 'cabin_letter_E', 'FamilySize', 'Pclass_2', 'Embarked_C', 'Parch_2', 'Parch_0', 'cabin_letter_C']

# %%
precision, recall, thresholds = plot_precision_recall_curve(y_val, preds_1)

# %%
auc_score = roc_auc_score(y_val, preds_1)
print("AUC Score = " , auc_score)
# Out:
# AUC Score =  0.8493426818580194

# %%
plot_shap_summary(classifier, X_val_encoded)
